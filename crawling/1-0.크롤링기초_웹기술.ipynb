# %% [markdown]
# ## 크롤링이란?
#
# * 크롤링은 웹페이지의 정보를 추출해내는 기술입니다.
# * 크롤링을 통해서 얻은 데이터는 비정형 데이터에 속합니다. (OpenAPI, Dataset은 정형데이터)
# * 따라서 웹페이지의 개편으로 구조의 변화가 있다면 잘 돌아가던 코드도 안 돌아갈 수도 있습니다.
# * 눈에는 보이나 가져올 수 없도록 막아놓은 정보도 있어 수집하기가 까다로운 영역입니다.
# * 하지만 인스타그램,유튜브 댓글, 네이버카페 글, 블로그 등은 하나의 집단의 의견,생각들이 반영된 공간이어서
# * 소셜마케팅,전략 기획 등을 위해 많이 활용됩니다.
# * 감춰진 데이터,동적으로 변하는 정보까지 가져오기 위해 selenium,scrapy등의 기술이 사용되며
# * 이것만 전문으로 하는 사람이 있을만큼 전문 영역입니다.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ## 웹 구조의 이해

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ## 주고 받은 데이터는?

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 웹페이지 구성

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 직관적 이해
#
# https://html-css-js.com/

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ## 크롤링을 위한 파이썬 라이브러리

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 주의 사항
#
# * 사이트에 무리가 가지 않도록 살살....
# * 저작권에도 신경쓰면서...
# * 언제 어떻게 사이트가 바뀔지 모름 -> 코드가 갑자기 안돌아 감.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ```
# [크롤링]
# 크롤링은 웹페이지의 정보를 추출해내는 기술입니다.
# 크롤링을 통해서 얻은 데이터를 비정형 데이터에 속합니다. (OpenAPI, Dataset은 정형데이터)
# 따라서 웹페이지의 개편으로 구조의 변화가 있다면 잘 돌아가던 코드도 안 돌아갈 수도 있습니다.
# 눈에는 보이나 가져올 수 없도록 막아놓은 정보도 있어 수집하기가 까다로운 영역입니다.
# 하지만 인스타그램,유튜브 댓글, 네이버카페 글, 블로그 등은 하나의 집단의 의견,생각들이 반영된 공간이어서
# 소셜마케팅,전략 기획 등을 위해 많이 활용됩니다.
# 감춰진 데이터,동적으로 변하는 정보까지 가져오기 위해 selenium,scrapy등의 기술이 사용되며
# 이것만 전문으로 하는 사람이 있을만큼 전문 영역입니다.
# ```
